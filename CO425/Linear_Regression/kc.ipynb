# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
df = pd.read_csv("../kc_house_data.csv")
X = df.drop("price", axis = 1)
y = df.price
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
# data preprocessing
df.isnull().sum()
# Out:
# id               0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.pairplot(df, x_vars=['bedrooms', 'bathrooms', 'sqft_lot', 'zipcode'], y_vars='price', height=7, aspect=0.5, kind='reg')

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.5972523544206676

# %%
reg.coef_
# Out:
# array([-1.09249330e-06, -4.69896048e+04,  1.84540597e+04,  1.67928816e+02,
#         2.66911907e-01,  8.90570816e+01,  7.88717341e+01, -4.06998605e+02,
#         6.66357471e+05, -4.61716121e+05,  7.90808979e+01, -3.53852087e-01])
