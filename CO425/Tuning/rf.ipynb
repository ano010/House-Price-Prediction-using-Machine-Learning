# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import joblib
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, MinMaxScaler
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

df = pd.read_csv("../house_data_colombo_cluster1.csv")


rf = RandomForestRegressor()

X = df.drop('price', axis = 1)
y = df['price']

clf = GridSearchCV(rf, {
    'n_estimators': [10, 20, 50, 70, 100, 120, 130, 140, 150, 200],
    'max_features': [None, 1, 2, 3, 4, 5],
    'max_depth': [1, 2, 5, 10, 15, 20, 25]
}, cv =5, return_train_score = False)

clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.032785      0.003125         0.002998        0.000632
# 1         0.052381      0.001360         0.003201        0.000398
# 2         0.146916      0.024599         0.007393        0.002151
# 3         0.190697      0.011656         0.008591        0.001847
# 4         0.302830      0.041277         0.010998        0.002281
# ..             ...           ...              ...             ...
# 415       0.786154      0.028098         0.045178        0.016401
# 416       0.906292      0.089959         0.040381        0.000495
# 417       0.971047      0.087080         0.043383        0.001024
# 418       0.998039      0.068301         0.045774        0.000400
# 419       1.381217      0.107152         0.063764        0.005745
#
#     param_max_depth param_max_features param_n_estimators  \
# 0                 1               None                 10
# 1                 1               None                 20
# 2                 1               None                 50
# 3                 1               None                 70
# 4                 1               None                100
# ..              ...                ...                ...
# 415              25                  5                120
# 416              25                  5                130
# 417              25                  5                140
# 418              25                  5                150
# 419              25                  5                200
#
#                                                 params  split0_test_score  \
# 0    {'max_depth': 1, 'max_features': None, 'n_esti...           0.393814
# 1    {'max_depth': 1, 'max_features': None, 'n_esti...           0.393509
# 2    {'max_depth': 1, 'max_features': None, 'n_esti...           0.393752
# 3    {'max_depth': 1, 'max_features': None, 'n_esti...           0.393737
# 4    {'max_depth': 1, 'max_features': None, 'n_esti...           0.393944
# ..                                                 ...                ...
# 415  {'max_depth': 25, 'max_features': 5, 'n_estima...           0.756713
# 416  {'max_depth': 25, 'max_features': 5, 'n_estima...           0.757083
# 417  {'max_depth': 25, 'max_features': 5, 'n_estima...           0.757934
# 418  {'max_depth': 25, 'max_features': 5, 'n_estima...           0.753738
# 419  {'max_depth': 25, 'max_features': 5, 'n_estima...           0.757609
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.386660           0.386057           0.417650
# 1             0.386846           0.385317           0.417100
# 2             0.391500           0.384180           0.417098
# 3             0.387442           0.380619           0.418742
# 4             0.386771           0.382424           0.417194
# ..                 ...                ...                ...
# 415           0.766512           0.783273           0.808288
# 416           0.768836           0.779802           0.810375
# 417           0.770805           0.784897           0.811917
# 418           0.768054           0.784436           0.810540
# 419           0.770240           0.781622           0.811548
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.389906         0.394817        0.011745              303
# 1             0.390858         0.394726        0.011556              304
# 2             0.393219         0.395950        0.011116              300
# 3             0.390459         0.394200        0.013013              308
# 4             0.390509         0.394168        0.012135              309
# ..                 ...              ...             ...              ...
# 415           0.780135         0.778984        0.017493               12
# 416           0.782163         0.779652        0.017757                8
# 417           0.777950         0.780701        0.017977                3
# 418           0.781059         0.779565        0.018894                9
# 419           0.779613         0.780126        0.017858                5
#
# [420 rows x 16 columns]
